# %%
import pandas as pd

# %%
bc = pd.read_csv('BankChurners.csv')

# %%
bc.head(10)
# Out:
#    CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0  768805383  Existing Customer            45      M                3
# 1  818770008  Existing Customer            49      F                5
# 2  713982108  Existing Customer            51      M                3
# 3  769911858  Existing Customer            40      F                4
# 4  709106358  Existing Customer            40      M                3
# 5  713061558  Existing Customer            44      M                2
# 6  810347208  Existing Customer            51      M                4
# 7  818906208  Existing Customer            32      M                0
# 8  710930508  Existing Customer            37      M                3
# 9  719661558  Existing Customer            48      M                2
#
#   Education_Level Marital_Status Income_Category Card_Category  \
# 0     High School        Married     $60K - $80K          Blue
# 1        Graduate         Single  Less than $40K          Blue
# ...

# %%
bc.tail(7)
# Out:
#        CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 10120  710841183  Existing Customer            54      M                1
# 10121  713899383  Existing Customer            56      F                1
# 10122  772366833  Existing Customer            50      M                2
# 10123  710638233  Attrited Customer            41      M                2
# 10124  716506083  Attrited Customer            44      F                1
# 10125  717406983  Attrited Customer            30      M                2
# 10126  714337233  Attrited Customer            43      F                2
#
#       Education_Level Marital_Status Income_Category Card_Category  \
# 10120     High School         Single     $60K - $80K          Blue
# 10121        Graduate         Single  Less than $40K          Blue
# 10122        Graduate         Single     $40K - $60K          Blue
# 10123         Unknown       Divorced     $40K - $60K          Blue
# ...

# %%
bc.dtypes
# Out:
# CLIENTNUM                                                                                                                               int64
# Attrition_Flag                                                                                                                         object
# Customer_Age                                                                                                                            int64
# Gender                                                                                                                                 object
# Dependent_count                                                                                                                         int64
# Education_Level                                                                                                                        object
# ...

# %%
bc = pd.read_csv('BankChurners.csv', index_col='Income_Category')

# %%
bc.rename(columns = {"CLIENTNUM": "Client_Number", "Customer_Age": "Age", "Income_Category": "Income"})
# Out:
#                  Client_Number     Attrition_Flag  Age Gender  \
# Income_Category
# $60K - $80K          768805383  Existing Customer   45      M
# Less than $40K       818770008  Existing Customer   49      F
# $80K - $120K         713982108  Existing Customer   51      M
# Less than $40K       769911858  Existing Customer   40      F
# $60K - $80K          709106358  Existing Customer   40      M
# ...                        ...                ...  ...    ...
# $40K - $60K          772366833  Existing Customer   50      M
# $40K - $60K          710638233  Attrited Customer   41      M
# Less than $40K       716506083  Attrited Customer   44      F
# $40K - $60K          717406983  Attrited Customer   30      M
# Less than $40K       714337233  Attrited Customer   43      F
#
#                  Dependent_count Education_Level Marital_Status Card_Category  \
# Income_Category
# $60K - $80K                    3     High School        Married          Blue
# ...

# %%
bc_education_category = bc[["CLIENTNUM", "Education_Level", "Card_Category"]]
bc_education_category
# Out:
#                  CLIENTNUM Education_Level Card_Category
# Income_Category
# $60K - $80K      768805383     High School          Blue
# Less than $40K   818770008        Graduate          Blue
# $80K - $120K     713982108        Graduate          Blue
# Less than $40K   769911858     High School          Blue
# $60K - $80K      709106358      Uneducated          Blue
# ...                    ...             ...           ...
# $40K - $60K      772366833        Graduate          Blue
# $40K - $60K      710638233         Unknown          Blue
# Less than $40K   716506083     High School          Blue
# $40K - $60K      717406983        Graduate          Blue
# Less than $40K   714337233        Graduate        Silver
#
# [10127 rows x 3 columns]

# %%
bc[bc["Marital_Status"] == "Married"]
# Out:
#                  CLIENTNUM     Attrition_Flag  Customer_Age Gender  \
# Income_Category
# $60K - $80K      768805383  Existing Customer            45      M
# $80K - $120K     713982108  Existing Customer            51      M
# $60K - $80K      709106358  Existing Customer            40      M
# $40K - $60K      713061558  Existing Customer            44      M
# $120K +          810347208  Existing Customer            51      M
# ...                    ...                ...           ...    ...
# $120K +          708564858  Attrited Customer            33      M
# Less than $40K   720841533  Existing Customer            29      M
# $80K - $120K     712503408  Existing Customer            57      M
# Less than $40K   716506083  Attrited Customer            44      F
# Less than $40K   714337233  Attrited Customer            43      F
#
#                  Dependent_count Education_Level Marital_Status Card_Category  \
# Income_Category
# ...

# %%
bc[(bc["Card_Category"] == "Blue") & (bc["Marital_Status"] == "Married") & (bc["Months_on_book"]>40)]
# Out:
#                  CLIENTNUM     Attrition_Flag  Customer_Age Gender  \
# Income_Category
# $40K - $60K      710821833  Existing Customer            65      M
# Less than $40K   712396908  Existing Customer            57      F
# $40K - $60K      806160108  Existing Customer            61      M
# Less than $40K   708508758  Attrited Customer            62      F
# $80K - $120K     789124683  Existing Customer            54      M
# ...                    ...                ...           ...    ...
# $120K +          789398733  Existing Customer            56      M
# $60K - $80K      767348733  Existing Customer            56      M
# $40K - $60K      719900733  Existing Customer            60      M
# $80K - $120K     827440458  Attrited Customer            48      M
# Less than $40K   709646433  Attrited Customer            59      F
#
#                  Dependent_count Education_Level Marital_Status Card_Category  \
# Income_Category
# ...

# %%
bc[bc["Card_Category"].isin(["Silver", "Gold"])]
# Out:
#                  CLIENTNUM     Attrition_Flag  Customer_Age Gender  \
# Income_Category
# $120K +          810347208  Existing Customer            51      M
# $60K - $80K      818906208  Existing Customer            32      M
# Less than $40K   785432733  Existing Customer            42      F
# $40K - $60K      773146383  Existing Customer            50      F
# $60K - $80K      712030833  Attrited Customer            48      M
# ...                    ...                ...           ...    ...
# $60K - $80K      719848008  Existing Customer            39      M
# $60K - $80K      715474083  Existing Customer            51      M
# $80K - $120K     718225683  Existing Customer            56      M
# $120K +          708564858  Attrited Customer            33      M
# Less than $40K   714337233  Attrited Customer            43      F
#
#                  Dependent_count Education_Level Marital_Status Card_Category  \
# Income_Category
# ...

# %%
bc.loc[bc["Customer_Age"]>=35, "CLIENTNUM"]
# Out:
# Income_Category
# $60K - $80K       768805383
# Less than $40K    818770008
# $80K - $120K      713982108
# Less than $40K    769911858
# $60K - $80K       709106358
#                     ...
# Less than $40K    713899383
# $40K - $60K       772366833
# $40K - $60K       710638233
# Less than $40K    716506083
# Less than $40K    714337233
# Name: CLIENTNUM, Length: 9392, dtype: int64

# %%
bc.loc[bc["Marital_Status"]=="Single", "Gender"]
# Out:
# Income_Category
# Less than $40K    F
# $60K - $80K       M
# $80K - $120K      M
# $80K - $120K      M
# $80K - $120K      M
#                  ..
# $80K - $120K      M
# Unknown           F
# $60K - $80K       M
# Less than $40K    F
# $40K - $60K       M
# Name: Gender, Length: 3943, dtype: object

# %%
bc.iloc[0:10, 1:3]
# Out:
#                     Attrition_Flag  Customer_Age
# Income_Category
# $60K - $80K      Existing Customer            45
# Less than $40K   Existing Customer            49
# $80K - $120K     Existing Customer            51
# Less than $40K   Existing Customer            40
# $60K - $80K      Existing Customer            40
# $40K - $60K      Existing Customer            44
# $120K +          Existing Customer            51
# $60K - $80K      Existing Customer            32
# $60K - $80K      Existing Customer            37
# $80K - $120K     Existing Customer            48

# %%
bc.iloc[0:3, 15:-2]
# Out:
#                  Total_Amt_Chng_Q4_Q1  Total_Trans_Amt  Total_Trans_Ct  \
# Income_Category
# $60K - $80K                     1.335             1144              42
# Less than $40K                  1.541             1291              33
# $80K - $120K                    2.594             1887              20
#
#                  Total_Ct_Chng_Q4_Q1  Avg_Utilization_Ratio
# Income_Category
# $60K - $80K                    1.625                  0.061
# Less than $40K                 3.714                  0.105
# $80K - $120K                   2.333                  0.000

# %%
bc["Months_Active_12_mon"] = (bc["Total_Relationship_Count"] - bc["Months_Inactive_12_mon"])

# %%
bc.insert(
    loc = 13, 
    column = "Months_on_book - Total_Relationship_Count", 
    value = (bc["Months_on_book"] - bc["Total_Relationship_Count"])
)

# %%
sbc = pd.Series(
    data = ['Less than $40K', "Existing Customer",49,"F",5,"Graduate","Single", "Blue",44,6,1,2,8256,864,7392,1.541,1291,33,3.714,0.105,5.6861e-05,0.99994, None, None], 
    index = bc.columns, 
    name = 99999999
)

# %%
bc = pd.read_csv('BankChurners.csv', index_col='CLIENTNUM')

# %%
bc = bc.append(sbc)
# Out:
# C:\Users\Kate\AppData\Local\Temp\ipykernel_512\1765828397.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   bc = bc.append(sbc)

# %%
bc.tail(5)
# Out:
#               Attrition_Flag  Customer_Age Gender  Dependent_count  \
# CLIENTNUM
# 710638233  Attrited Customer            41      M                2
# 716506083  Attrited Customer            44      F                1
# 717406983  Attrited Customer            30      M                2
# 714337233  Attrited Customer            43      F                2
# 99999999   Existing Customer            49      F                5
#
#           Education_Level Marital_Status Income_Category Card_Category  \
# CLIENTNUM
# 710638233         Unknown       Divorced     $40K - $60K          Blue
# 716506083     High School        Married  Less than $40K          Blue
# 717406983        Graduate        Unknown     $40K - $60K          Blue
# 714337233        Graduate        Married  Less than $40K        Silver
# 99999999         Graduate         Single             NaN          Blue
#
#            Months_on_book  Total_Relationship_Count  ...  \
# ...

# %%
bc.to_csv('BankChurners.csv')

# %%
del bc["Months_Active_12_mon"]

# %%
del bc["Months_on_book - Total_Relationship_Count"]

# %%
bc = pd.read_csv('BankChurners.csv', index_col='CLIENTNUM')

# %%
bc.drop(labels = 99999999)
# Out:
#               Attrition_Flag  Customer_Age Gender  Dependent_count  \
# CLIENTNUM
# 768805383  Existing Customer            45      M                3
# 818770008  Existing Customer            49      F                5
# 713982108  Existing Customer            51      M                3
# 769911858  Existing Customer            40      F                4
# 709106358  Existing Customer            40      M                3
# ...                      ...           ...    ...              ...
# 772366833  Existing Customer            50      M                2
# 710638233  Attrited Customer            41      M                2
# 716506083  Attrited Customer            44      F                1
# 717406983  Attrited Customer            30      M                2
# 714337233  Attrited Customer            43      F                2
#
#           Education_Level Marital_Status Income_Category Card_Category  \
# CLIENTNUM
# ...
